# %%
from datasets import load_dataset

# %%
from datasets import load_dataset

df = load_dataset("mohanty/PlantVillage","default")

# %%
print(df)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 129783
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 33133
#     })
# })
